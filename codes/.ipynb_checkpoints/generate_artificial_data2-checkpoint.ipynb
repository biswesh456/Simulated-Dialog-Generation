# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AutoTokenizer, AutoModelWithLMHead, BertTokenizer, LongformerTokenizer, LongformerModel
import torch, json, random
import numpy as np

# %%
import gpt.Model as userModel
# import gpt_agent.Data as agentData
import gpt_agent.Model as agentModel
import gpt_query.Model as queryModel
import bert_siamese.Model as userSiameseModel
import bert_siamese_agent.Model as agentSiameseModel

# %%
domain_key = 'taxi'
percentage = '10'

# %%
d_train= json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/train_db.json'))
d_rest = json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/restaurant_db.json'))
d_hotel = json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/hotel_db.json'))
d_police = json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/police_db.json'))
d_hosp = json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/hospital_db.json'))
d_attr = json.load(open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/db/attraction_db.json'))
d_taxi = [{
  "taxi_colors" : ["black","white","red","yellow","blue","grey"],
  "taxi_types":  ["toyota","skoda","bmw","honda","ford","audi","lexus","volvo","volkswagen","tesla"],
  "taxi_phone": ["^[0-9]{10}$"]
}]
entity_db_map = {'train':d_train, 'restaurant': d_rest, 'police': d_police, 'hospital': d_hosp, 'attraction': d_attr, 'taxi':d_taxi,'hotel':d_hotel}

# %%
query_key = {'train' : list(d_train[0].keys()), 
             'restaurant' : list(d_rest[0].keys()), 
             'hotel' : list(d_hotel[0].keys()),
             'police' : list(d_police[0].keys()),
             'hospital' : list(d_hosp[0].keys()),
             'attraction' : list(d_attr[0].keys()),
             'taxi' : ['taxi_colors', 'taxi_types', 'taxi_phone'],
            }

# %%
bert_model_name='bert-base-uncased'
longformer_model_name='allenai/longformer-base-4096'
user_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
agent_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# agent_tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-small")
query_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
bert_tokenizer = BertTokenizer.from_pretrained(bert_model_name)
longformer_tokenizer = LongformerTokenizer.from_pretrained(longformer_model_name)

# %%
def getStringKB(kb):
    if topic == 'police':
        return '[KB] Total = 1 [KB]'
    elif topic == 'taxi':
        return '[KB] Total = 1 [KB]'
    
    final_str =  "[KB] " + " Total = " + str(len(kb)) + ' [KB]'
#     for k in kb:
#         final_str +=  k + " : " + str(kb[k]) + " | "

#     final_str += ' [KB]'
    return final_str

# %%
def getUserModel():
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/user/gpt_hospital2/checkpoint_hred_user__best_128_512_0.0001_1.pth.tar'
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/user/gpt_hotel2/checkpoint_hred_user__best_128_512_0.0001_1.pth.tar'
    model_path = '/disk1/home/biswesh/rsync1/models/multiwiz/user/'+domain_key+'_'+percentage+'p/checkpoint_hred_user__best_128_512_1e-05_1.pth.tar' #takes only the last one context
    checkpoint = torch.load(model_path)
    load_args = checkpoint['args']
    model = userModel.GPT(load_args)
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
def getAgentModel():
    model_path = '/disk1/home/biswesh/rsync1/models/multiwiz/agent/'+domain_key+'_'+percentage+'p/checkpoint_hred_user__best_128_512_1.pth.tar'
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/agent/gpt_hotel2/checkpoint_hred_user__best_128_512_1.pth.tar'
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/agent/gpt_hospital2/checkpoint_hred_user__best_128_512_1.pth.tar'

    checkpoint = torch.load(model_path)
    load_args = checkpoint['args']
    model = agentModel.GPT(load_args)
    model.cuda()
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
def getQueryModel():
    model_path = '/disk1/home/biswesh/rsync1/models/multiwiz/query/'+domain_key+'_'+percentage+'p/checkpoint_hred_user__best_128_512_1.pth.tar'
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/query/gpt_hotel2/checkpoint_hred_user__best_128_512_1.pth.tar'
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/query/gpt_hospital2/checkpoint_hred_user__best_128_512_1.pth.tar'

    checkpoint = torch.load(model_path)
    load_args = checkpoint['args']
    model = queryModel.GPT(load_args)
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
def getUserSiameseModel():
    model_path = '/disk1/home/biswesh/rsync1/models/multiwiz/siamese/user/'+domain_key+'_'+percentage+'p/checkpoint_hred_user__best_128_128_1.pth.tar' # with neg as generated response
#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/siamese/user/train1/checkpoint_hred_user__best_128_128_1.pth.tar'
    checkpoint = torch.load(model_path)
    load_args = checkpoint['args']
    model = userSiameseModel.Siamese_margin(load_args)
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
def getAgentSiameseModel():
    model_path = '/disk1/home/biswesh/rsync1/models/multiwiz/siamese/agent/'+domain_key+'_'+percentage+'p/checkpoint_hred_user__best_128_128_1.pth.tar' # with neg as generated response

#     model_path = '/u/vineeku6/storage/gaurav/biswesh/models/multiwiz/siamese/agent/train2/checkpoint_hred_user__best_128_128_1.pth.tar'
    checkpoint = torch.load(model_path)
    load_args = checkpoint['args']
    model = agentSiameseModel.Siamese_margin(load_args)
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
def getData():
    data_path = '/disk1/home/biswesh/rsync1/data/multiwiz/user/single_goal_topic_'+percentage+'p/goals_new.json'
    with open(data_path) as f:
        goals = json.load(f)
    
    data_path = '/disk1/home/biswesh/rsync1/data/multiwiz/agent/single_goal_topic_'+percentage+'p/rest_state.json'
    with open(data_path) as f:
        state = json.load(f)
    return goals, state
#     with open(data_dir+"test_tgt.json") as f:
#         responses = json.load(f)

#     with open(data_dir+"test_goal.json") as f:
#         goals = json.load(f)
     
#     test_context = contexts[domain_key]
# #     for key in contexts:
# #         test_context.extend(contexts[key])

#     test_response = responses[domain_key]
# #     for key in responses:
# #         test_response.extend(responses[key])    
        
#     test_goal = goals[domain_key]
# #     for key in goals:
# #         test_goal.extend(goals[key])

#     data_dir = '/disk1/home/biswesh/rsync1/data/multiwiz/agent/single_goal_topic_'+percentage+'p/'
#     with open(data_dir+"test_input.json") as f:
#         agent_contexts = json.load(f)

#     with open(data_dir+"test_tgt.json") as f:
#         agent_responses = json.load(f)
        
#     with open(data_dir+"test_query.json") as f:
#         agent_queries = json.load(f)    
        
#     with open(data_dir+"test_kb.json") as f:
#         kb = json.load(f)    
        
#     test_kb = kb[domain_key]
    
#     return test_context, test_response, test_goal, test_kb, agent_queries[domain_key]

# %%
user_gpt = getUserModel()
user_model = user_gpt.model
user_model.eval()
user_model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
agent_gpt = getAgentModel()
agent_model = agent_gpt.model
agent_model.eval()
agent_model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
query_gpt = getQueryModel()
query_model = query_gpt.model
query_model.eval()
query_model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
user_siamese_model = getUserSiameseModel()
user_siamese_model.eval()
user_siamese_model.cuda()
# Out:
# Siamese_margin(
#   (longformer_model): LongformerModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(4098, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (FC1): Linear(in_features=768, out_features=128, bias=True)
#   (FC2): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
agent_siamese_model = getAgentSiameseModel()
agent_siamese_model.eval()
agent_siamese_model.cuda()
# Out:
# Siamese_margin(
#   (longformer_model): LongformerModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(4098, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): LongformerSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (query_global): Linear(in_features=768, out_features=768, bias=True)
#               (key_global): Linear(in_features=768, out_features=768, bias=True)
#               (value_global): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (FC1): Linear(in_features=768, out_features=128, bias=True)
#   (FC2): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
goals, state = getData()

# %%
seed = 25
def set_seed():
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
# goal_length = {'restaurant':537, 'hotel':273, 'train':171, 'attraction':132, 'taxi':102 }
goal_length = {'restaurant':1074, 'hotel':546, 'train':342, 'attraction':264, 'taxi':200 }

# %%
importantKeys = {}
importantKeys['train'] = ['leaveAt', 'destination', 'departure', 'arriveBy', 'day', 'people']
importantKeys['hotel'] = ['name', 'area', 'parking', 'pricerange', 'stars', 'internet', 'type', 'stay', 'day', 'people']
importantKeys['restaurant'] = ['food', 'pricerange', 'name', 'area', 'people', 'day', 'time']
importantKeys['attraction'] = ['type', 'name', 'area']
importantKeys['taxi'] = ['leaveAt', 'destination', 'departure', 'arriveBy']

def formatQuery(query, context):
    query = query.lower().replace('[q]', '').split('|')
    new_query = query[0].strip()
    joined_context = " ".join(context[1::2])
    intermediate_query = {}

    for q in query[1:]:
        q = q.split('=')
        if len(q)>=2:
            key = q[0].strip()
            val = "".join(q[1:]).strip()
            if val != '*' and val != 'dontcare' and val != 'none':
                if key == 'name' and not any([v in joined_context for v in val.split(' ')]):
                    val = '*'
            if val == '':
                val = '*'
                        
            intermediate_query[key] = val
    
    if 'departure' in intermediate_query and 'destination' in intermediate_query:
            if intermediate_query['departure'] == intermediate_query['destination']:
                if 'from' in joined_context or 'depart' in joined_context:
                    intermediate_query['destination'] = '*'
                else:
                    intermediate_query['departure'] = '*'
    
    for key in importantKeys[domain_key]: 
        if key in intermediate_query:
            new_query += ' | ' + key + ' = ' + intermediate_query[key] 
        else:
            new_query += ' | ' + key + ' = ' + '*'
    
    new_query = '[Q] ' + new_query + ' [Q]'

    return new_query

# %%
def getKB(query, utt_no, fail_book, failed):
    not_kb = ['people', 'time', 'stay']
    if domain_key != 'train':
        not_kb.append('day')
    
    db = entity_db_map[domain_key]
    final_query = {}
    fail_query = {}
    
    query = query.lower().replace('[q]', '')
    
    for q in query.split(' | ')[1:]:
        q = q.split(' = ')
        q[0] = q[0].strip()
        q[1] = q[1].strip()
        
        if q[1] != 'not mentioned' and q[1]!='dontcare' and q[1]!='none' and q[1]!='' and q[1]!='*':
            fail_query[q[0]] = q[1]
        
        for k in query_key[domain_key]:
            if q[0] == k and q[1] != 'not mentioned' and q[1]!='dontcare' and q[1]!='none' and q[1]!='' and q[1]!='*':
                final_query[k] = q[1]
                
    for k in fail_book:
        if k in fail_query and fail_book[k] == fail_query[k] and failed == False:
                return '[KB] Total = 0 [KB]', {}
    
    ret = []
    for row in db:
        match = True
        for k in final_query.keys():
#             print(k, final_query[k], row[k])
            if(k == "arriveBy"):
                try:
                    if int(final_query[k][:2]) > int(row[k][:2]):
                        match=True
                    elif int(final_query[k][:2]) == int(row[k][:2]) and int(final_query[k][3:]) >= int(row[k][3:]):
                        match=True
                    else:
                        match=False
                        break
                except: 
                    match=True
            elif(k == "leaveAt"):
                try:
                    if int(row[k][:2]) > int(final_query[k][:2]):
                        match=True
                    elif int(row[k][:2]) == int(final_query[k][:2]) and int(row[k][3:]) >= int(final_query[k][3:]):
                        match=True
                    else:
                        match=False
                        break   
                except:
                    match=True
            else:
                val = row[k]
                semi = final_query
                domain = domain_key
                val = val.strip()
                semi[k] = semi[k].strip()
                if domain == 'attraction' and k == 'type':
                    semi[k] = semi[k].replace(' ', '')
                    val = val.replace(' ', '')
                    if semi[k] == 'pool':
                        semi[k] = 'swimmingpool'
                    if val == 'pool':
                        val = 'swimmingpool'
                    if semi[k] == 'sports' or semi[k] == 'multiplesports':
                        semi[k] = 'mutliple sports'
                    if val == 'mutliplesports' or val == 'sports':
                        val = 'mutliple sports'
                if k == 'parking' or k == 'internet':
                    semi[k] = semi[k].replace('free', 'yes')
                    val = val.replace('free', 'yes')
                if k == 'food':
                    semi[k] = semi[k].replace('south indian', 'indian')
                    val = val.replace('south indian', 'indian')
                if k == 'name':
                    val = val.replace('the', '')
                    semi[k] = semi[k].replace('the', '')
                    val = val.replace("b & b", "bed and breakfast")
                    semi[k] = semi[k].replace("b & b", "bed and breakfast")
                    val = val.replace("restaurant", "")
                    semi[k] = semi[k].replace("restaurant", "")
                    if "hotel" in val and 'gonville' not in val:
                        val = val.replace(" hotel", "")
                    if "hotel" in semi[k] and 'gonville' not in semi[k]:
                            semi[k] = semi[k].replace("hotel", "")
                    
                
                if (val!=semi[k]):
                    match=False
                    break

        if(match):
            ret.append(row)

    if len(ret) == 0:
        return  "[KB] " + " Total = 0 [KB]", {}
    else:
#         return '[KB] Total : ' + str(len(ret)) + ' ' + str(getStringKB(ret[0])), ret[0]
         return "[KB] " + " Total = " + str(len(ret)) + ' [KB]', ret[0]

# %%
def adjustScore(query, last_context, response, kb, turn_no, entire_context):
    query = query.lower().replace('[q]', '').split('|')[1:]
    belief_state = {}
    score = 0
    for q in query:
        q = q.split('=')
        if len(q)>=2:
            key = q[0].strip()
            belief_state[key] = "".join(q[1:]).strip()
            
    requestables = ['phone', 'number', 'address', 'postcode', 'reference', 'id']
    for r in requestables:
        if r == 'number':
            r = 'phone'
        if r in last_context:
            if ' ['+domain_key+'_'+r+']' in response:
                score += 0.5  
        if r not in last_context:
            if ' ['+domain_key+'_'+r+']' in response:
                score += -0.1
                
    enquiry = ['area', 'name', 'price', 'internet', 'fee', 'travel time']
    for e in enquiry:
        if e == 'travel time':
            if 'minute' in response:
                score += 0.3
        elif e in last_context and e in response:
            score += 0.2
    
    # do not ask about slots if name is already provided
    if 'name' in belief_state and belief_state['name'] != '*':
        if '['+domain_key+'_'+'name]' not in entire_context and '['+domain_key+'_'+'name]' in response:
            return 0.2
        return 0
    
    if '0' in kb and domain_key != 'train':
        if ' no ' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
        elif ' not ' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
        elif 'unfortunate' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
        elif 'unavailable' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
        elif 'unsuccessful' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
        elif 'sorry' in response:
            score += 0.2
            if 'book' in context:
                score += 0.1
    elif domain_key != 'train':
        if ' no ' in response:
            score += -0.4
        elif ' not ' in response:
            score += -0.4
        elif 'unfortunate' in response:
            score += -0.4
        elif 'unavailable' in response:
            score += -0.4
        elif 'unsuccessful' in response:
            score += -0.4
        elif 'sorry' in response:
            score += -0.4
            
    if 'book' in context and 'book' in response:
        if '0' not in response and ' successful' in response:
            score += 0.3
    
    Flag = True
    if turn_no > 1: 
        Flag = False
    
    if domain_key == 'attraction' and turn_no>0:
        Flag = False
        
    if domain_key == 'taxi' and turn_no>0:
        if '[taxi_type]' not in entire_context and '[taxi_type]' in response:
            score += 0.2
        Flag = False
        
    if turn_no > 0:
        if '['+domain_key+'_'+'name]' not in entire_context and '['+domain_key+'_'+'name]' in response:
            score += 0.2
            print('ABC')
    
    if 'when' in response:
        if ' leave' in response:
            if 'leaveat' in belief_state and belief_state['leaveat'] != '*':
                score -= 0.25
            elif 'leaveat' in belief_state and Flag:
                print('q1')
                score += 0.2

        if ' arrive' in response:
            if 'arriveby' in belief_state and belief_state['arriveby'] != '*':
                score += -0.25
            elif 'arriveby' in belief_state and Flag:
                score += 0.2
                print('q2')

    if ('what' in response and 'what about' not in response) or 'do you' in response or 'is there' in response:
        if ' time' in response and (' leave' in response or ' depart' in response):
            if 'leaveat' in belief_state and belief_state['leaveat'] != '*':
                score += -0.25
            elif 'leaveat' in belief_state and Flag:
                score += 0.2
                print('q3')

        elif ' time' in response and ' arrive' in response:
            if 'arriveby' in belief_state and belief_state['arriveby'] != '*':
                score += -0.25
            elif 'arriveby' in belief_state and Flag:
                score += 0.2
                print('q4')

#         elif ' time' in response:
#             if 'leaveat' in belief_state and 'arriveby' in belief_state and belief_state['arriveby'] != '*' and belief_state['leaveat'] != '*':
#                 score += -0.3
#             elif 'leaveat' in belief_state and 'arriveby' in belief_state and Flag:
#                 score += 0.2
#                 print('q5')

        elif ' destination' in response:
            if 'destination' in belief_state and belief_state['destination'] != '*':
                score += -0.3
            elif 'destination' in belief_state and Flag:
                score += 0.4
                print('q6')

        elif ' departure' in response:
            if 'departure' in belief_state and belief_state['departure'] != '*':
                score += -0.3
            elif 'departure' in belief_state and Flag:
                score += 0.2
                print('q7')

        elif ' day' in response:
            if 'day' in belief_state and belief_state['day'] != '*':
                score += -0.25
            elif 'day' in belief_state and Flag:
                score += 0.15
                print('q8')
                
        elif ' area' in response or ' part of town' in response:
            if 'area' in belief_state and belief_state['area'] != '*':
                score += -0.25
            elif 'area' in belief_state and Flag:
                score += 0.1
                print('q9')
                
        elif ' type of food' in response or ' kind of food' in response:
            if 'food' in belief_state and belief_state['food'] != '*':
                score += -0.25
            elif 'food' in belief_state:
                score += 0.3
                print('q10')
                
        elif ' price range' in response:
            if 'pricerange' in belief_state and belief_state['pricerange'] != '*':
                score += -0.25
            elif 'pricerange' in belief_state and Flag:
                score += 0.2
                print('q11')

    if 'where' in response:
        if ' depart' in response or ' leaving from' in response or ' departure' in response or 'travelling from' in response or 'to and from' in response:
            if 'departure' in belief_state and belief_state['departure'] != '*':
                score += -0.3
            elif 'departure' in belief_state and Flag:
                score += 0.2
                print('q12')

        elif ' destination' in response or ' going to' or ' travelling to' in response or 'to and from' in response:
            if 'destination' in belief_state and belief_state['destination'] != '*':
                score += -0.3
            elif 'destination' in belief_state and Flag:
                score += 0.4
                print('q13')

    if 'how many' in response:
        if ' people' in response or ' ticket' in response:
            if 'people' in belief_state and belief_state['people'] != '*':
                score += -0.25
            elif 'people' in belief_state and turn_no >2 and ('thank' not in response or 'bye' not in response):
                score += 0.1

    if 'which' in response:
        if ' day' in response:
            if 'day' in belief_state and belief_state['day'] != '*':
                score += -0.25
            elif 'day' in belief_state and Flag:
                score += 0.15
                print('q14')
                
        elif ' area' in response or ' part of town' in response:
            if 'area' in belief_state and belief_state['area'] != '*':
                score += -0.25
            elif 'area' in belief_state and Flag:
                score += 0.1
                print('q15')

        elif ' type of food' in response or ' kind of food' in response:
            if 'food' in belief_state and belief_state['food'] != '*':
                score += -0.25
            elif 'food' in belief_state and Flag:
                score += 0.3
                print('q16')
                
        elif ' price range' in response:
            if 'pricerange' in belief_state and belief_state['pricerange'] != '*':
                score += -0.25
            elif 'pricerange' in belief_state and Flag:
                score += 0.15
                print('q16')
    
    return score

# %%
def formatResponse(agent_response):
    agent_response = agent_response.replace(',', ' , ')
    agent_response = agent_response.replace('.', ' . ')
    agent_response = agent_response.replace('?', ' ? ')
    agent_response = agent_response.replace('!', ' ! ')
    agent_response = agent_response.replace('[', ' [')
    agent_response = agent_response.replace(']', '] ')
    agent_response = agent_response.replace('  ', ' ')
    if domain_key == 'restaurant':
        agent_response = agent_response.replace('[attraction_address]', '[restaurant_address]') 
        agent_response = agent_response.replace('[attraction_phone]', '[restaurant_phone]') 
    if domain_key == 'attraction':
        agent_response = agent_response.replace('[restaurant_address]', '[attraction_address]') 
        agent_response = agent_response.replace('[restaurant_phone]', '[attraction_phone]') 
    
    agent_response = agent_response.strip()
    return agent_response

# %%
def formatUserResponse(user_response):
    user_response = user_response.strip()
    if len(user_response) > 0 and user_response[-1] != '.' and user_response[-1] != '?' and user_response[-1] != '!':
        user_response = user_response + '.'
    return user_response

# %%
def adjustUserScore(goal, response, turn_no, entire_context):
    score = 0
    requestables = ['phone', 'number', 'address', 'postcode', 'reference', 'id']
    enquiry = ['area', 'name', 'price', 'internet', 'fee', 'travel time']
    for r in requestables:
        if r in goal and r not in entire_context:
            score = 0.1
        if ('thank' in response or 'bye' in response) and r not in entire_context:
            score = -0.2
                
    for e in enquiry:
        if ('thank' in response or 'bye' in response) and e not in entire_context:
            score = -0.1
    
    
    return score

# %%
set_seed()
final_contexts = []
final_queries = []
final_kbs = []

for g in range(min(goal_length[domain_key], len(goals[domain_key]))):
    if g < len(state[domain_key]) and 'fail_book' in state[domain_key][g]:
        fail_book = state[domain_key][g]['fail_book']
        print(fail_book)
    else:
        fail_book = {}
    
    failed = False
    flag = 0
    context = ['[st@rt]']
    queries = []
    kbs = []
    resp_no = 10
    goal = goals[domain_key][g] 
    start_index = 0
    for i in range(6):
        new_user_input = user_tokenizer.encode(goal + ' GOAL ' + " ".join(context), return_tensors='pt')
        if len(new_user_input)>1022:
            flag = 1
    #     response = user_model.generate(new_user_input.cuda(), max_length=500, pad_token_id=user_tokenizer.eos_token_id, num_beams=20, num_return_sequences=resp_no, early_stopping=True)
        response = user_model.generate(new_user_input[:1022].cuda(), max_length=1000, pad_token_id=user_tokenizer.eos_token_id, do_sample=True, top_k=resp_no, top_p=0.65, num_return_sequences=resp_no, no_repeat_ngram_size=4, early_stopping=True)

        max_score = 0
        user_response = ''
        for j in range(resp_no):
            response_j = user_tokenizer.decode(response[j][new_user_input.shape[1]:]).replace('<|endoftext|>', '')
            response_j = response_j.replace('[', '')
            response_j = response_j.replace('User', '')
            response_j = response_j.replace(']', '')
            if response_j.replace(' ', '') == '' or response_j.replace(' ', '') == '.' or response_j.replace(' ', '') == ',':
                pass
            elif len(response_j.replace('?', '.').split('.')) > 4:
                pass
            else:
                response_j = response_j.strip()
                if response_j[0] == ',' or response_j[0] == '!':
                    response_j = response_j[1:]
                response_j = '[User] ' + response_j.strip()

                input_context = " ".join(context)
                encode = longformer_tokenizer.batch_encode_plus([[input_context, response_j]])
                input_ids = torch.tensor(encode.input_ids[:1022]).cuda()
                attention_mask = torch.tensor(encode.attention_mask[:1022]).cuda()

                score = user_siamese_model(input_ids, attention_mask)
                score += adjustUserScore(goal, response_j, i, " ".join(context))
                if response_j == '':
                    score = -1
                if score > max_score and len(response_j)<1023:
                    user_response = response_j
                    max_score = score
#                 print('response : ', j, " : ", response_j, " score ", score.item(), '\n')
#         print('*'*100)
    #    user_response = input('User : ')
        if user_response == '':
            flag = 1
        context.append(formatUserResponse(user_response))

        if user_response.strip().lower().find('e*d') != -1 :
            break

        query_input = query_tokenizer.encode(" ".join(context)[:1022], return_tensors='pt')
        query_response = query_model.generate(query_input.cuda(), max_length=1022, pad_token_id=query_tokenizer.eos_token_id, num_beams=5, num_return_sequences=5, early_stopping=True)

        query = agent_tokenizer.decode(query_response[0][query_input.shape[1]:]).replace('<|endoftext|>', '')
#         print('1 ', query, '\n')
        query = formatQuery(query, context)
        queries.append(query)
#         print('2 ', query, '\n')

        kb, kb_dict = getKB(query, i, fail_book, failed)
        kbs.append(kb)
#         print('KB : ', kb)
        new_agent_input = agent_tokenizer.encode(query + " " + kb + " " + " ".join(context), return_tensors='pt')
        if len(new_agent_input)>1022:
            flag = 1
        response = agent_model.generate(new_agent_input[:1022].cuda(), max_length=1000, pad_token_id=agent_tokenizer.eos_token_id, do_sample=True, top_k=resp_no, top_p=0.7, num_return_sequences=resp_no, early_stopping=True)

        max_score = 0
        agent_response = ''
        if flag == 0:
            for j in range(len(response)):
                response_j = agent_tokenizer.decode(response[j][new_agent_input.shape[1]:]).replace('<|endoftext|>', '')
                response_j = response_j.replace('[Agent]', '')
                if response_j.replace(' ', '') == '':
                    pass
                elif len(response_j.replace('?', '.').split('.')) > 3:
                    pass
                else:
                    response_j = '[Agent]' + response_j
                    encode = longformer_tokenizer.batch_encode_plus([[query + ' ' + kb + ' ' + " ".join(context), response_j]])
                    input_ids = torch.tensor(encode.input_ids[:1022]).cuda()
                    attention_mask = torch.tensor(encode.attention_mask[:1022]).cuda()

                    score = agent_siamese_model(input_ids, attention_mask)
#                     print(score.item())
                    score = score + adjustScore(query, context[-1], response_j, kb, i, " ".join(context[start_index:]), )
                    if response_j == '':
                        score = -1
                    if score > max_score and len(response_j)<1023:
                        agent_response = response_j
                        max_score = score

#                     print('response : ', j, " : ", response_j, " score ", score.item(), '\n')

#         response = agent_model.generate(new_agent_input.cuda(), max_length=1000, pad_token_id=agent_tokenizer.eos_token_id, num_beams=resp_no, num_return_sequences=resp_no, early_stopping=True)
#         for j in range(len(response)):
#             response_j = agent_tokenizer.decode(response[j][new_agent_input.shape[1]:]).replace('<|endoftext|>', '')

#             if response_j.replace(' ', '') == '':
#                 pass
#             elif len(response_j.replace('?', '.').split('.')) > 3:
#                 pass
#             else:
#                 encode = longformer_tokenizer.batch_encode_plus([[query + ' ' + kb + ' ' + " ".join(context), response_j]])
#                 input_ids = torch.tensor(encode.input_ids).cuda()
#                 attention_mask = torch.tensor(encode.attention_mask).cuda()

#                 score = agent_siamese_model(input_ids, attention_mask)

#                 if score > max_score:
#                     agent_response = response_j
#                     max_score = score
#                 print('response : ', j, " : ", response_j, " score ", score.item(), '\n')

#         print('*'*100)
    #     agent_response = input('Agent : ')
    #     context.append(agent_response)
        if agent_response == '':
            flag = 1
        agent_response = formatResponse(agent_response)
        if flag == 0:
            context.append(agent_response)
        if any(word in agent_response for word in [' no ', ' not ', 'unavailable', 'unfortunate', 'sorry', 'unable', 'unsuccessful']):
                    failed = True
                    start_index = i
                    
        if flag == 1:
            print("GOAL : ", g, ' ', goal)
            final_ctx = []
            for i,ctx in enumerate(context):
                if ctx.find('[st@rt]') == -1 and ctx.find('e*d') == -1:
                    final_ctx.append(ctx)
                    print(ctx)

            final_contexts.append(final_ctx)
            final_queries.append(queries)
            final_kbs.append(kbs)
            print('*'*100)
            break
    
    if flag == 0:
        print("GOAL : ", g, ' ', goal)
        final_ctx = []
        for i,ctx in enumerate(context):
            if ctx.find('[st@rt]') == -1 and ctx.find('e*d') == -1:
                final_ctx.append(ctx)
                print(ctx)

        final_contexts.append(final_ctx)
        final_queries.append(queries)
        final_kbs.append(kbs)
        print('*'*100)
# Out:
# q7
# q13
# q12
# q13
# q13
# q3
# q12
# q12
# q12
# GOAL :  0   You want to book a [key] taxi [key] . The taxi should depart from [key] rajmahal [key] and should [key] leave after 01:30 [key] . The taxi should go to [key] queens' college [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] yes, i'll be leaving from rajmamal.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# q3
# q3
# q1
# GOAL :  1   You want to book a [key] taxi [key] . The taxi should depart from [key] the good luck chinese food takeaway [key] and should go to [key] alpha-milton guest house [key] . The taxi should [key] arrive by 18:15 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from the good luck restaurant to alpha-minton guest house.
# [Agent] i would be happy to help with your request . what time would you like to leave ?
# [User] please leave by 18:30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q3
# GOAL :  2   You want to book a [key] taxi [key] . The taxi should depart from [key] the junction [key] and should [key] arrive by 04:00 [key] . The taxi should go to [key] regency gallery [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today. i need to go to regency gallery.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] yes i need to leave by 04:30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i hi, i'm sorry i forgot to get the contact number. i'm sure you will be happy to help me.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# q13
# q1
# q13
# q13
# q12
# q2
# q12
# q1
# q13
# q1
# GOAL :  3   You want to book a [key] taxi [key] . The taxi should depart from [key] mumford theatre [key] and should go to [key] darrys cookhouse and wine shop [key] . The taxi should [key] arrive by 24:45 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] darry, i'm leaving from mumford theatre.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you! that is all i needed.
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# GOAL :  4   You want to book a [key] taxi [key] . The taxi should go to [key] museum of classical archaeology [key] and should depart from [key] curry king [key] . The taxi should [key] leave after 10:15 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi departing from curry king to museum of classical archeology at 10:15. i need a car type and contact number.
# [Agent] i have booked you a [taxi_type] , the contact number is [taxi_phone] .
# [User] thank you! that is all i needed.
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q13
# q13
# q1
# q12
# q12
# q12
# q13
# q13
# q12
# GOAL :  5   You want to book a [key] taxi [key] . The taxi should go to [key] williams art and antiques [key] and should depart from [key] pembroke college [key] . The taxi should [key] arrive by 15:30 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where will you leave from ?
# [User] yes, i'll be leaving from pembrokke college.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# q12
# GOAL :  6   You want to book a [key] taxi [key] . The taxi should [key] leave after 16:45 [key] and should go to [key] the cambridge punter [key] . The taxi should depart from [key] magdalene college [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a cambridge punters taxi today.
# [Agent] where will you be departing from ?
# [User] magdalen college. i am departing from magdalene.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q1
# GOAL :  7   You want to book a [key] taxi [key] . The taxi should go to [key] arbury lodge guesthouse [key] and should depart from [key] grafton hotel restaurant [key] . The taxi should [key] leave after 04:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from grafton hotel guesthouse to arbury lodge guestshouse.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] please. i need to leave after 04.15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q7
# q12
# q13
# q13
# q12
# q13
# q3
# q7
# q12
# q7
# GOAL :  8   You want to book a [key] taxi [key] . The taxi should [key] leave after 03:00 [key] and should depart from [key] anatolia [key] . The taxi should go to [key] the cambridge corn exchange [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today after 3:00.
# [Agent] i would be happy to help , where would you like to leave from ?
# [User] i would like to go to the cambridge.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q12
# q1
# q13
# q12
# q12
# q13
# q13
# q12
# q12
# GOAL :  9   You want to book a [key] taxi [key] . The taxi should [key] arrive by 19:00 [key] and should depart from [key] alpha-milton guest house [key] . The taxi should go to [key] cambridge university botanic gardens [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] the taxi should depart from alpha-minton guest house.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q3
# q12
# q13
# q12
# q13
# q13
# q13
# q12
# q1
# GOAL :  10   You want to book a [key] taxi [key] . The taxi should depart from [key] hamilton lodge [key] and should go to [key] restaurant one seven [key] . The taxi should [key] arrive by 21:30 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] hmm, i'm leaving from hamilton lodge.
# [Agent] i have booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q3
# q3
# GOAL :  11   You want to book a [key] taxi [key] . The taxi should go to [key] graffiti [key] and should depart from [key] travellers rest [key] . The taxi should [key] leave after 16:45 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i want to book an taxi from travellers rest to graffiti. i need to leave after 16.45.
# [Agent] i would be happy to help , what time would you like to leave ?
# [User] 16:45. i need it to be picked up at graffiti.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q13
# q12
# q12
# q13
# q13
# q3
# q13
# q1
# q12
# GOAL :  12   You want to book a [key] taxi [key] . The taxi should depart from [key] jinling noodle bar [key] and should go to [key] tenpin [key] . The taxi should [key] arrive by 21:45 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help , where will you leave from ?
# [User] jinlings noodle bar. i will leave from jinling noodle bar.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q12
# q13
# q13
# q13
# q13
# q1
# q13
# q13
# q13
# GOAL :  13   You want to book a [key] taxi [key] . The taxi should [key] leave after 21:15 [key] and should depart from [key] backstreet bistro [key] . The taxi should go to [key] the cambridge punter [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request where will you leave from ?
# [User] yes i will leave from backstreet bismro.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i hi, i'm sorry to have to be so long. i'm leaving from backstreet.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# q13
# q13
# q12
# q13
# q12
# q13
# q13
# q12
# GOAL :  14   You want to book a [key] taxi [key] . The taxi should depart from [key] clowns cafe [key] and should [key] arrive by 23:00 [key] . The taxi should go to [key] the hotpot [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request where would you like to leave from ?
# [User] yes, i am departing from clowns cafe.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you so much. i need you to arrive by 23.00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# q3
# GOAL :  15   You want to book a [key] taxi [key] . The taxi should depart from [key] charlie chan [key] and should [key] leave after 12:15 [key] . The taxi should go to [key] cotto [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from charlie chann to cotto after 12:45.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] please leave after 12.45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# GOAL :  16   You want to book a [key] taxi [key] . The taxi should depart from [key] cambridge artworks [key] and should [key] leave after 18:00 [key] . The taxi should go to [key] lynne strover gallery [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from cambridge artwork to lynne stroker gallery after 18:30.
# [Agent] i have booked for you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you! that's all i needed.
# [Agent] i hope you have a wonderful day .
# ****************************************************************************************************
# q13
# q13
# q1
# q1
# q12
# q13
# q13
# q13
# q12
# q13
# GOAL :  17   You want to book a [key] taxi [key] . The taxi should [key] arrive by 03:00 [key] and should depart from [key] panahar [key] . The taxi should go to [key] cambridge arts theatre [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] yes i will be leaving from panahar.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# GOAL :  18   You want to book a [key] taxi [key] . The taxi should depart from [key] jesus green outdoor pool [key] and should go to [key] la margherita [key] . The taxi should [key] leave after 23:00 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i want to book an taxi from jesus blue outdoor pool to la margheritas.
# [Agent] i can book that for you . when would you like to leave ?
# [User] no, i want to leave after 23.00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# GOAL :  19   You want to book a [key] taxi [key] . The taxi should depart from [key] whipple museum of the history of science [key] and should [key] arrive by 21:00 [key] . The taxi should go to [key] restaurant two two [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi departing from whipple museum and arriving by 21:30.
# [Agent] i can help you with that . what time would you like to leave ?
# [User] that is 21:00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you!
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q12
# q13
# q12
# q13
# q12
# q2
# q13
# q2
# q13
# q1
# GOAL :  20   You want to book a [key] taxi [key] . The taxi should depart from [key] broxbourne train station [key] and should go to [key] city stop restaurant [key] . The taxi should [key] leave after 20:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] the taxi should depart at broxbourne.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you for your help.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# q12
# q12
# q12
# q12
# GOAL :  21   You want to book a [key] taxi [key] . The taxi should [key] leave after 05:45 [key] and should depart from [key] the missing sock [key] . The taxi should go to [key] great saint mary's church [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i want to book the taxi to great saint mARY's church after 05:35.
# [Agent] where will you be departing from ?
# [User] the taxi should be departing from the missing sock.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you for your help!
# [Agent] you are welcome thank you you are welcome thank you thank you thank you thank you have a wonderful day goodbye
# ****************************************************************************************************
# q12
# q13
# q1
# q3
# q13
# q12
# q13
# q3
# q13
# q13
# GOAL :  22   You want to book a [key] taxi [key] . The taxi should go to [key] pizza express Fen Ditton [key] and should [key] leave after 17:15 [key] . The taxi should depart from [key] king's college [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] pizza express. i'm leaving from king's college.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you! that is all i needed.
# [Agent] thank you for contacting us .
# ****************************************************************************************************
# GOAL :  23   You want to book a [key] taxi [key] . The taxi should [key] arrive by 02:45 [key] and should go to [key] camboats [key] . The taxi should depart from [key] kings hedges learner pool [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from kings hedges to camboats at 2:45.
# [Agent] i would be happy to help with your request , where are you coming from ?
# [User] please, i'm arriving from kings hedes.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i hi, thank you for your help.
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q7
# q7
# q7
# q7
# q3
# q3
# GOAL :  24   You want to book a [key] taxi [key] . The taxi should depart from [key] gallery at twelve a high street [key] and should go to [key] rajmahal [key] . The taxi should [key] leave after 03:45 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi to go to rajmaghal after 03:30.
# [Agent] i would be happy to help , what is your departure site ?
# [User] my destination is gallery at twelve.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# q3
# GOAL :  25   You want to book a [key] taxi [key] . The taxi should go to [key] curry king [key] and should [key] arrive by 07:15 [key] . The taxi should depart from [key] sheep's green and lammas land park fen causeway [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from sheep's green to curry king at 07:15.
# [Agent] what time would you like to leave ?
# [User] please. i will need to leave by 07:45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i like it!
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# GOAL :  26   You want to book a [key] taxi [key] . The taxi should [key] arrive by 24:15 [key] and should go to [key] jinling noodle bar [key] . The taxi should depart from [key] pembroke college [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from pembroken college to jinling noodles noodle bar.
# [Agent] i have booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] you are welcome . have a great trip .
# ****************************************************************************************************
# q12
# q12
# q12
# GOAL :  27   You want to book a [key] taxi [key] . The taxi should [key] leave after 11:15 [key] and should go to [key] riverside brasserie [key] . The taxi should depart from [key] saint johns chop house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today. i need to go to riverside brassery after 11:45.
# [Agent] where will you be departing from ?
# [User] will be departing from saint johns chopping house.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you for your assistance.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# q13
# q3
# GOAL :  28   You want to book a [key] taxi [key] . The taxi should depart from [key] saint catharine's college [key] and should [key] arrive by 01:15 [key] . The taxi should go to [key] loch fyne [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi departing from saint catharine and arriving by 01:45.
# [Agent] where will you leave from ?
# [User] loch is i leaving from saint cathararine's college?
# [Agent] sure ! what time would you like to leave ?
# [User] i need to leave by 01:25.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q3
# q13
# q12
# q3
# q13
# q3
# q13
# q12
# q13
# GOAL :  29   You want to book a [key] taxi [key] . The taxi should depart from [key] little saint mary's church [key] and should go to [key] trinity college [key] . The taxi should [key] leave after 24:45 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] yes, i will be leaving from little saint maries church.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you so much!
# [Agent] thank you for using our services !
# ****************************************************************************************************
# q13
# q3
# q3
# GOAL :  30   You want to book a [key] taxi [key] . The taxi should depart from [key] parkside police station [key] and should go to [key] little seoul [key] . The taxi should [key] arrive by 06:30 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi departing from parkside police center and arriving by 06:45.
# [Agent] where will you leave from ?
# [User] my destination is little seoul.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i like the app? that's all i need today.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# q3
# q1
# q3
# q3
# GOAL :  31   You want to book a [key] taxi [key] . The taxi should depart from [key] the cherry hinton village centre [key] and should go to [key] la raza [key] . The taxi should [key] leave after 10:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from cherry hinton to la raza.
# [Agent] i can help you with that . when would you like to leave ?
# [User] after 10:45 please.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# GOAL :  32   You want to book a [key] taxi [key] . The taxi should [key] arrive by 17:30 [key] and should go to [key] la mimosa [key] . The taxi should depart from [key] nusha [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from nusha to la mimosa.
# [Agent] i would be happy to help with your request , what time would you like to leave ?
# [User] 16:30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you for your help!
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q13
# q13
# q13
# q13
# q12
# q13
# q13
# q7
# q12
# GOAL :  33   You want to book a [key] taxi [key] . The taxi should [key] leave after 04:30 [key] and should depart from [key] nandos city centre [key] . The taxi should go to [key] castle galleries [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to be picked up ?
# [User] nandros city centre. i would like to be pick up at castle galleries.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q3
# q13
# q3
# q12
# q7
# q13
# q3
# q1
# GOAL :  34   You want to book a [key] taxi [key] . The taxi should [key] arrive by 14:00 [key] and should depart from [key] sesame restaurant and bar [key] . The taxi should go to [key] saint johns chop house [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] please. i need to be picked up from sesame restaurant, bar and pick up at the saint johns.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q1
# q12
# q13
# q13
# q13
# q7
# q12
# q13
# q13
# GOAL :  35   You want to book a [key] taxi [key] . The taxi should depart from [key] broxbourne train station [key] and should [key] arrive by 23:30 [key] . The taxi should go to [key] india house [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] please, i'm leaving from broxbourne station.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q1
# q1
# q12
# q13
# q12
# q13
# q13
# GOAL :  36   You want to book a [key] taxi [key] . The taxi should go to [key] pizza express Fen Ditton [key] and should [key] leave after 11:45 [key] . The taxi should depart from [key] sidney sussex college [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] please. i would like to go to pizza express Fen ditton.
# [Agent] ok , i have booked you a [taxi_type] , the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] your booking has been completed . have a great trip .
# ****************************************************************************************************
# q1
# GOAL :  37   You want to book a [key] taxi [key] . The taxi should [key] leave after 03:15 [key] and should go to [key] the good luck chinese food takeaway [key] . The taxi should depart from [key] bloomsbury restaurant [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi departing from bloomsbury after 03:45 to the good luck choinese food takeaway.
# [Agent] i would be happy to help with your request . when would you like to leave ?
# [User] after 3:15, i need to get there by 3:15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q13
# q3
# q13
# q12
# q13
# q12
# q12
# q12
# q3
# GOAL :  38   You want to book a [key] taxi [key] . The taxi should [key] arrive by 01:45 [key] and should go to [key] the varsity restaurant [key] . The taxi should depart from [key] gonville hotel [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] where will you leave from ?
# [User] the taxi will be departing from gonville hotel.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q13
# q12
# q7
# q12
# q13
# q12
# q12
# q12
# q13
# GOAL :  39   You want to book a [key] taxi [key] . The taxi should go to [key] corpus christi [key] and should [key] leave after 03:30 [key] . The taxi should depart from [key] prezzo [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] yes, i will be departing from prezzo.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# GOAL :  40   You want to book a [key] taxi [key] . The taxi should [key] arrive by 19:15 [key] and should depart from [key] chiquito restaurant bar [key] . The taxi should go to [key] saint barnabas press gallery [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from chiquito to saint barnaba press gallery.
# [Agent] i would be happy to help ! what time would you like to leave ?
# [User] the taxi will be arriving by 19:45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q13
# q1
# q12
# q13
# q13
# q1
# q13
# q12
# q12
# GOAL :  41   You want to book a [key] taxi [key] . The taxi should depart from [key] funky fun house [key] and should [key] arrive by 06:15 [key] . The taxi should go to [key] curry garden [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] yes, i will be leaving from funky fun house.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# q3
# GOAL :  42   You want to book a [key] taxi [key] . The taxi should [key] arrive by 10:00 [key] and should depart from [key] cambridge lodge restaurant [key] . The taxi should go to [key] cambridge book and print gallery [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from cambridge lodge to cambridge book.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] the taxi should arrive by 10.00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you! you're all set!
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q3
# q13
# q13
# q13
# GOAL :  43   You want to book a [key] taxi [key] . The taxi should [key] leave after 19:15 [key] and should depart from [key] ask [key] . The taxi should go to [key] rice house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi departing from ask and arriving from ask.
# [Agent] i can help you with that , where are you going ?
# [User] i'm going to rice house.
# [Agent] i booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] you are welcome . have a great trip .
# ****************************************************************************************************
# q3
# GOAL :  44   You want to book a [key] taxi [key] . The taxi should [key] arrive by 21:15 [key] and should depart from [key] el shaddai [key] . The taxi should go to [key] cocum [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from el shaddais to cocum.
# [Agent] what time would you like to leave ?
# [User] the taxi should depart from el shadai and should depart at 21:15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] this is all i needed.
# [Agent] you are welcome ! have a nice day !
# ****************************************************************************************************
# q7
# q13
# q12
# q3
# q13
# q13
# q13
# q12
# q13
# GOAL :  45   You want to book a [key] taxi [key] . The taxi should go to [key] the gandhi [key] and should [key] arrive by 01:45 [key] . The taxi should depart from [key] leverton house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today and i need to arrive by 0145.
# [Agent] i would be happy to help , where will you leave from ?
# [User] the taxi will leave from leverton house.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you!
# [Agent] you are welcome . have a nice day .
# ****************************************************************************************************
# q12
# q3
# q12
# q13
# q13
# q12
# q12
# q12
# q1
# q3
# GOAL :  46   You want to book a [key] taxi [key] . The taxi should depart from [key] leverton house [key] and should go to [key] cambridge lodge restaurant [key] . The taxi should [key] leave after 08:00 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that . where will you leave from ?
# [User] cambridge loden. i'll be departing from leverton house and going to cambridge lodge.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i like the app? what is the contact number and car type?
# [Agent] the contact number is [taxi_phone] .
# [User] thank you for your assistance!
# [Agent] have a wonderful day .
# ****************************************************************************************************
# q12
# q13
# q13
# q3
# q12
# q12
# q12
# q12
# q13
# GOAL :  47   You want to book a [key] taxi [key] . The taxi should depart from [key] sidney sussex college [key] and should go to [key] ely train station [key] . The taxi should [key] arrive by 17:15 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] my destination is ely train.
# [Agent] i have booked you a [taxi_type] .
# [User] that is all i need today.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# GOAL :  48   You want to book a [key] taxi [key] . The taxi should depart from [key] the man on the moon [key] and should go to [key] bangkok city [key] . The taxi should [key] leave after 05:00 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from the man on moon to bangkok city after 05:30.
# [Agent] what time would you like to leave by ?
# [User] than i need to be picked up at 05:00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# q3
# GOAL :  49   You want to book a [key] taxi [key] . The taxi should go to [key] jinling noodle bar [key] and should depart from [key] warkworth house [key] . The taxi should [key] arrive by 23:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from warkworth to jinling noodles noodle bar at 23:15.
# [Agent] what time would you like to leave ?
# [User] today is today. i need to leave by 23:45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# GOAL :  50   You want to book a [key] taxi [key] . The taxi should go to [key] rosa's bed and breakfast [key] and should depart from [key] saint catharine's college [key] . The taxi should [key] leave after 13:00 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from saint catharine to rosa's at 13:00.
# [Agent] i have booked for you a [taxi_type] , the contact number is [taxi_phone] . is there anything else you need to know ?
# [User] yes, i need a car type.
# [Agent] the contact number is [taxi_phone] . can i help with anything else ?
# [User] no, i will be happy to help you.
# [Agent] thank you have a wonderful day
# ****************************************************************************************************
# q3
# GOAL :  51   You want to book a [key] taxi [key] . The taxi should [key] arrive by 23:30 [key] and should depart from [key] wandlebury country park [key] . The taxi should go to [key] tandoori palace [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from wandlebury to tandoor i need to be picked up by 23:45.
# [Agent] i would be happy to help with your request , what time would you like to leave ?
# [User] today i need to leave from wandlewood country park.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q2
# q1
# q12
# q1
# q3
# q13
# q13
# q13
# q13
# q12
# GOAL :  52   You want to book a [key] taxi [key] . The taxi should go to [key] riverside brasserie [key] and should [key] arrive by 19:30 [key] . The taxi should depart from [key] cambridge arts theatre [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] where are you coming from ?
# [User] I'm departing from cambridge arts theater.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# GOAL :  53   You want to book a [key] taxi [key] . The taxi should go to [key] the cherry hinton village centre [key] and should [key] arrive by 18:15 [key] . The taxi should depart from [key] ashley hotel [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from ashley hotel to cherry hinton.
# [Agent] what time would you like to leave ?
# [User] 18:15. i will need to be picked up at 18:15 and arrive by 18.15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q13
# q13
# q13
# q13
# q1
# q7
# q12
# q13
# q13
# GOAL :  54   You want to book a [key] taxi [key] . The taxi should [key] leave after 17:00 [key] and should go to [key] churchill college [key] . The taxi should depart from [key] the varsity restaurant [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to be picked up ?
# [User] the taxi should be picked up at churchill college.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q12
# q12
# q12
# q3
# GOAL :  55   You want to book a [key] taxi [key] . The taxi should go to [key] the cambridge corn exchange [key] and should [key] arrive by 11:45 [key] . The taxi should depart from [key] little seoul [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i want to book my taxi to cambridge corn Exchange by 11: 45.
# [Agent] i would be happy to help with your request , where will you be departing from ?
# [User] cambridge corn is the place to be departing from little seoul.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you for your help.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# q1
# q2
# q2
# q1
# q12
# GOAL :  56   You want to book a [key] taxi [key] . The taxi should go to [key] express by holiday inn cambridge [key] and should depart from [key] leverton house [key] . The taxi should [key] arrive by 06:45 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today. i need a destination by holiday inn.
# [Agent] sure ! when would you like to leave ?
# [User] after 6:45.
# [Agent] i have booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you! that is all i needed.
# [Agent] your booking has been completed ! have a nice day !
# ****************************************************************************************************
# GOAL :  57   You want to book a [key] taxi [key] . The taxi should depart from [key] hotel du vin and bistro [key] and should go to [key] golden house [key] . The taxi should [key] arrive by 07:00 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today. i need a hotel du vino and bistron.
# [Agent] i would be happy to help with your request , where would you like to be picked up ?
# [User] yes i would like to be pick up at golden house.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q1
# GOAL :  58   You want to book a [key] taxi [key] . The taxi should depart from [key] vue cinema [key] and should go to [key] clowns cafe [key] . The taxi should [key] arrive by 11:30 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from vue cinema to clowns cafe.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] 11:30. i need it today.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i hi! that's all i needed today!
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# GOAL :  59   You want to book a [key] taxi [key] . The taxi should depart from [key] cambridge arts theatre [key] and should go to [key] peking restaurant [key] . The taxi should [key] leave after 12:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from cambridge arts theater to peking restaurant.
# [Agent] i would be happy to help , where will you leave from ?
# [User] yes, i will be leaving from cambridge art theatre.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] please confirm that the taxi is departing from cambridge.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
#
# ****************************************************************************************************
# q2
# q3
# GOAL :  60   You want to book a [key] taxi [key] . The taxi should [key] leave after 05:00 [key] and should go to [key] the lensfield hotel [key] . The taxi should depart from [key] tang chinese [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from tang chinese to lensfield hotel.
# [Agent] sure ! when would you like to arrive ?
# [User] after 05:30, please.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# GOAL :  61   You want to book a [key] taxi [key] . The taxi should go to [key] saint barnabas press gallery [key] and should depart from [key] the gardenia [key] . The taxi should [key] arrive by 02:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from saint barnaba press gallery to saint barnabasa press gallery.
# [Agent] i have booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] you are welcome . have a great trip .
# ****************************************************************************************************
# q3
# q3
# GOAL :  62   You want to book a [key] taxi [key] . The taxi should [key] arrive by 15:00 [key] and should depart from [key] arbury lodge guesthouse [key] . The taxi should go to [key] rajmahal [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from arbury lodge Guesthouse to rajmahsal at 15:00.
# [Agent] i can help with that , what time would you like to leave ?
# [User] 15:00 will be the perfect time to arrive.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q1
# GOAL :  63   You want to book a [key] taxi [key] . The taxi should depart from [key] bridge guest house [key] and should go to [key] sidney sussex college [key] . The taxi should [key] arrive by 07:15 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from bridge guest house to sidney susdys college.
# [Agent] i would be happy to help with your request , what time would you like to leave ?
# [User] please be sure that i am leaving by 07:00 and that i am actually leaving by 07.15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# q1
# q12
# q13
# q3
# q13
# q13
# q12
# q13
# q12
# GOAL :  64   You want to book a [key] taxi [key] . The taxi should go to [key] cocum [key] and should [key] leave after 09:00 [key] . The taxi should depart from [key] hobsons house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to be picked up ?
# [User] cocum. i need to be picked from hobsons. house.
# [Agent] i have booked you a [taxi_type] , the contact number is [taxi_phone] .
# [User] that is all i need today.
# [Agent] you are welcome . have a nice day .
# [User] have a great day!
# [Agent] thank you for using our services .
# ****************************************************************************************************
# q3
# GOAL :  65   You want to book a [key] taxi [key] . The taxi should go to [key] worth house [key] and should depart from [key] rajmahal [key] . The taxi should [key] arrive by 16:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from rajmal to worth house.
# [Agent] i would be happy to help with your request . what time would you like to leave ?
# [User] 16:15. i need to be picked up at 16:15, please.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q12
# q3
# GOAL :  66   You want to book a [key] taxi [key] . The taxi should go to [key] ugly duckling [key] and should depart from [key] dojo noodle bar [key] . The taxi should [key] arrive by 19:30 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i want to book to ugly duckling. i need a taxi.
# [Agent] i can help you with that , where will you be departing from ?
# [User] from dojo noodler bar. i will be departing from dojo.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q1
# q3
# q3
# GOAL :  67   You want to book a [key] taxi [key] . The taxi should depart from [key] the lensfield hotel [key] and should go to [key] peking restaurant [key] . The taxi should [key] arrive by 06:15 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from lensfield hotel to peking restaurant.
# [Agent] i would be happy to help with your request , what time would you like to leave and arrive ?
# [User] the taxi should arrive by 06,15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# GOAL :  68   You want to book a [key] taxi [key] . The taxi should go to [key] anatolia [key] and should depart from [key] castle galleries [key] . The taxi should [key] arrive by 20:45 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i want to book an anatolia taxi. the taxi should go from castle galleries to anatolia.
# [Agent] i have booked you a [taxi_type] , the contact number is [taxi_phone] .
# [User] thank you!
# [Agent] you are welcome . have a great trip .
# ****************************************************************************************************
# q1
# ...
# [User] i need a taxi from rajmohal to kohinoo.
# [Agent] what time would you like to leave ?
# [User] 14:00, please.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# GOAL :  77   You want to book a [key] taxi [key] . The taxi should go to [key] holy trinity church [key] and should [key] arrive by 15:30 [key] . The taxi should depart from [key] don pasquale pizzeria [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from holy trinity christian church to holy trinity pizza restaurant.
# [Agent] what time would you like to leave ?
# [User] the taxi should depart at 15:30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q12
# q2
# q12
# q12
# q13
# q13
# q13
# q2
# q12
# GOAL :  78   You want to book a [key] taxi [key] . The taxi should depart from [key] kohinoor [key] and should go to [key] saint barnabas press gallery [key] . The taxi should [key] leave after 11:00 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] kohineoor, i will be departing from kohinur.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i thank you!
# [Agent] you are welcome . have a great day !
# ****************************************************************************************************
# q7
# q12
# q12
# q12
# q12
# q13
# q13
# q13
# q1
# GOAL :  79   You want to book a [key] taxi [key] . The taxi should depart from [key] the fez club [key] and should go to [key] the cambridge punter [key] . The taxi should [key] leave after 05:30 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where will you leave from ?
# [User] i'll be leaving from the fez.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# q1
# GOAL :  80   You want to book a [key] taxi [key] . The taxi should [key] leave after 18:30 [key] and should go to [key] jesus green outdoor pool [key] . The taxi should depart from [key] fitzbillies restaurant [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from jesus blue outdoor pool to jesus greens outdoor pool.
# [Agent] sure ! when would you like to leave ?
# [User] i would like to leave after 18.30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# GOAL :  81   You want to book a [key] taxi [key] . The taxi should [key] arrive by 13:15 [key] and should go to [key] primavera [key] . The taxi should depart from [key] curry queen [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today. i need to arrive by 1315 and should go there by primavera.
# [Agent] i can help you with that . when would you like to leave ?
# [User] at 13:15.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q3
# q13
# q12
# q3
# q13
# q12
# q12
# q7
# q13
# GOAL :  82   You want to book a [key] taxi [key] . The taxi should [key] leave after 11:15 [key] and should go to [key] kohinoor [key] . The taxi should depart from [key] worth house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i would be happy to help with your request , where would you like to leave from ?
# [User] kohinee. i need to go to kohinor.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q12
# q12
# q12
# q12
# q13
# q13
# q13
# q7
# q13
# q1
# GOAL :  83   You want to book a [key] taxi [key] . The taxi should go to [key] churchill college [key] and should depart from [key] emmanuel college [key] . The taxi should [key] leave after 21:30 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] my destination is churchill college.
# [Agent] i have booked a [taxi_type] for you .
# [User] thank you.
# [Agent] your booking has been completed . have a great trip .
# ****************************************************************************************************
# GOAL :  84   You want to book a [key] taxi [key] . The taxi should go to [key] nandos [key] and should [key] leave after 17:45 [key] . The taxi should depart from [key] royal spice [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from royal spice to nandos after 17: 45.
# [Agent] i have booked a [taxi_type] , the contact number is [taxi_phone] . can i help with anything else ?
# [User] no, i need a car.
# [Agent] i would be happy to help with anything else .
# [User] thank you.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# GOAL :  85   You want to book a [key] taxi [key] . The taxi should [key] arrive by 07:00 [key] and should depart from [key] ali baba [key] . The taxi should go to [key] wandlebury country park [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from ali baba to wandlebury. i want to be picked up by 07:01.
# [Agent] i have booked for you a [taxi_type] , the contact number is [taxi_phone] .
# [User] thank you! that is all i needed.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# q12
# q13
# q12
# q13
# q13
# q1
# q12
# q2
# q13
# q12
# GOAL :  86   You want to book a [key] taxi [key] . The taxi should [key] arrive by 19:15 [key] and should go to [key] avalon [key] . The taxi should depart from [key] primavera [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today.
# [Agent] i can help you with that , where would you like to leave from ?
# [User] i'm leaving from primavera.
# [Agent] i would be happy to help with your request . where will you be going ?
# [User] i'm going to avalon.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q12
# q12
# GOAL :  87   You want to book a [key] taxi [key] . The taxi should go to [key] williams art and antiques [key] and should [key] leave after 15:30 [key] . The taxi should depart from [key] cambridge museum of technology [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i want to book an iphone taxi. the taxi should go into williams arts and antiques and should leave after 15,30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q13
# q13
# q3
# q3
# GOAL :  88   You want to book a [key] taxi [key] . The taxi should go to [key] museum of archaelogy and anthropology [key] and should [key] arrive by 17:15 [key] . The taxi should depart from [key] cote [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi to arrive by 1715 from cote. i need a contact number and car type.
# [Agent] where are you coming from ?
# [User] from cote i'm going to museum of arch. anthropology.
# [Agent] i was able to book a [taxi_type] for you .
# [User] thank you! that's all i needed.
# [Agent] you are welcome . have a great trip .
# ****************************************************************************************************
# GOAL :  89   You want to book a [key] taxi [key] . The taxi should depart from [key] peterborough train station [key] and should go to [key] riverboat georgina [key] . The taxi should [key] leave after 05:15 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i want to book the taxi from peterborough to riverboat georgeina.
# [Agent] i have booked you a [taxi_type] . the contact number is [taxi_phone] .
# [User] thank you. that is all i needed.
# [Agent] you are welcome . have a great day .
# ****************************************************************************************************
# q13
# q13
# q13
# q13
# GOAL :  90   You want to book a [key] taxi [key] . The taxi should depart from [key] the good luck chinese food takeaway [key] and should go to [key] riverside brasserie [key] . The taxi should [key] arrive by 12:45 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i want to book my taxi. the taxi should depart at 12:45 and should go by riverside brassery.
# [Agent] i can help you with that , where would you like to be picked up ?
# [User] riverside golderie. i would like to be pick up at the river edge.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# q3
# GOAL :  91   You want to book a [key] taxi [key] . The taxi should depart from [key] london liverpool street train station [key] and should go to [key] club salsa [key] . The taxi should [key] leave after 01:30 [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from london london street train station to club salsa.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] i would like to leave after 01.30.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] please provide me with your contact number.
# [Agent] the contact number is [taxi_phone] .
# [User] thank you.
# [Agent] have a nice day .
# ****************************************************************************************************
# q1
# q1
# GOAL :  92   You want to book a [key] taxi [key] . The taxi should [key] leave after 14:00 [key] and should depart from [key] la margherita [key] . The taxi should go to [key] avalon [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi from la margarita to avalon.
# [Agent] i can help you with that . when would you like to leave ?
# [User] at 14:00, i need to get to avalon by 14:00.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# GOAL :  93   You want to book a [key] taxi [key] . The taxi should depart from [key] old schools [key] and should go to [key] the cambridge chop house [key] . The taxi should [key] arrive by 09:00 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from old schools to cambridge chop. i need to arrive by 09.00.
# [Agent] i would be happy to help , where are you coming from ?
# [User] my destination is old schools.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# GOAL :  94   You want to book a [key] taxi [key] . The taxi should [key] leave after 02:30 [key] and should go to [key] curry king [key] . The taxi should depart from [key] holy trinity church [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from holy trinity cathedral to curry king.
# [Agent] i can help you with that , what time would you like to leave ?
# [User] after 02:45, please.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# [User] i like the app?
# [Agent] sure ! when would you like to leave ?
# [User] i want to get there by 02:30.
# ****************************************************************************************************
# q13
# q13
# q13
# q13
# GOAL :  95   You want to book a [key] taxi [key] . The taxi should [key] leave after 05:45 [key] and should go to [key] da vinci pizzeria [key] . The taxi should depart from [key] williams art and antiques [key] . Make sure you get [key] contact number [key] and [key] car type [key]
# [User] i need a taxi departing from williams arts and antiques at 05:45.
# [Agent] i would be happy to help with your request , where are you coming from ?
# [User] my destination is da vinco pizzeria.
# [Agent] i have booked you a [taxi_type] .
# [User] thank you! that is all i needed.
# [Agent] have a nice day .
# ****************************************************************************************************
# q12
# q3
# q12
# q7
# q12
# GOAL :  96   You want to book a [key] taxi [key] . The taxi should go to [key] the lensfield hotel [key] and should depart from [key] christ's college [key] . The taxi should [key] leave after 21:30 [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today. i need a lensfield hotel.
# [Agent] where will you be departing from ?
# [User] christ's. i'll be departing from christ's college.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# q3
# q3
# GOAL :  97   You want to book a [key] taxi [key] . The taxi should go to [key] magdalene college [key] and should [key] arrive by 12:15 [key] . The taxi should depart from [key] kings lynn train station [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from kings lynn to magdalene.
# [Agent] i can help you with that . when would you like to leave ?
# [User] yes i would like to be picked up by 12:45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q3
# q3
# GOAL :  98   You want to book a [key] taxi [key] . The taxi should [key] leave after 04:15 [key] and should go to [key] hotel du vin and bistro [key] . The taxi should depart from [key] scott polar museum [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi today and i need a hotel du vino and bistros.
# [Agent] i can help you with that . what time would you like to leave ?
# [User] after 04:45, i will need to be picked up at hotel du vinos.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************
# q1
# GOAL :  99   You want to book a [key] taxi [key] . The taxi should depart from [key] the cambridge corn exchange [key] and should [key] leave after 18:15 [key] . The taxi should go to [key] bridge guest house [key] . Make sure you get [key] car type [key] and [key] contact number [key]
# [User] i need a taxi from cambridge corn to bridge guest house.
# [Agent] i would be happy to help with your request . when would you like to leave ?
# [User] i would like to be picked up at bridge guest house after 18:45.
# [Agent] booking completed ! booked car type [taxi_type] contact number [taxi_phone]
# ****************************************************************************************************

# %%
json.dump(final_contexts, open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/artificial_data/data_'+domain_key+'_'+percentage+'p.json','w'))

# %%
len(final_contexts), len(final_queries), len(final_kbs)

# %%
json.dump(final_kbs, open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/artificial_data/kb_'+domain_key+'_'+percentage+'p.json','w'))
json.dump(final_queries, open('/disk1/home/biswesh/goal_oriented_learning/createData/multiwoz21/artificial_data/query_'+domain_key+'_'+percentage+'p.json','w'))
